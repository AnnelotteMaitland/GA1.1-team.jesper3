# %% [markdown]
# So, my fucnction is subtract(a,b) it will take two values, such as a and b, and as the output it will present the result in the form of "When you subtract b from a you get: ..."

# %%
def subtract(a,b):
    c = a - b
    print (f'When you subtract b from a you get: {c}')

# %%
subtract (5,4)
subtract (6,10)
subtract (0.7,4)
subtract (A, 4)
# Out:
# When you subtract b from a you get: 1
# When you subtract b from a you get: -4
# When you subtract b from a you get: -3.3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 subtract (5,4)
#       2 subtract (6,10)
#       3 subtract (0.7,4)
# ----> 4 subtract (A, 4)
#
# NameError: name 'A' is not defined
